# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * Cities closer to the equador have higher temperatures but, interestingly, latitudes further from the equador in the north have lower temperatures than those further from the equador in the south. This is most likely because there are simply more cities in the northern end of the hemisphere, while the southern hemisphere is Antarctica, where there are no cities.
# * There are no clear patterns or relationships between latitude and humidity, cloudiness, or wind speed. Nor are there any clear relationships between longitude and any of the four measures of weather.
# * Interestingly, cloudiness seems to cluster around 0% and 100%.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import datetime as date

# Import API key
from config import key

# Incorporated citipy to determine city based on latitude and longitude

from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 640

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={key}&units={units}&q="
response = requests.get(query_url+cities[0]).json()

lats = []
temp = []
hums = []
cloud =[]
wndspd= []
country =[]
date = []
longs = []
good_cities = []

recordcount = 1
timeoutcounter = 1
print("Beginning Data Retrieval")     
print("-----------------------------")
for city in cities:
    response = requests.get(query_url + city).json()
    print(f"Processing Record {recordcount}: {city}")
    if timeoutcounter%10 == 0:
        time.sleep(5)
        
    try:
        lats.append(response["coord"]["lat"])
        temp.append(response['main']['temp'])
        hums.append(response['main']['humidity'])
        cloud.append(response['clouds']["all"])
        wndspd.append(response['wind']["speed"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        longs.append(response["coord"]["lon"])
        good_cities.append(city)
        timeoutcounter += 1
    
    except (KeyError, IndexError):
        print("City not found. Skipping...")
        cities.remove(city)
        pass
    recordcount = recordcount+1
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1: punta arenas
# Processing Record 2: aksu
# Processing Record 3: aksarka
# Processing Record 4: longyearbyen
# Processing Record 5: yellowknife
# Processing Record 6: barentsburg
# City not found. Skipping...
# Processing Record 7: mathbaria
# Processing Record 8: tilichiki
# Processing Record 9: siderno
# Processing Record 10: gravdal
# Processing Record 11: rio cuarto
# Processing Record 12: rikitea
# Processing Record 13: avarua
# Processing Record 14: dwarka
# Processing Record 15: tuatapere
# Processing Record 16: khatanga
# Processing Record 17: hobart
# Processing Record 18: avera
# Processing Record 19: souillac
# Processing Record 20: mataura
# Processing Record 21: la orilla
# Processing Record 22: chokurdakh
# Processing Record 23: kapaa
# Processing Record 24: kidal
# Processing Record 25: yinchuan
# Processing Record 26: tsihombe
# City not found. Skipping...
# Processing Record 27: busselton
# Processing Record 28: faanui
# Processing Record 29: acajutla
# Processing Record 30: akdepe
# Processing Record 31: mackenzie
# Processing Record 32: broken hill
# Processing Record 33: vostok
# Processing Record 34: vaini
# Processing Record 35: manica
# Processing Record 36: hilo
# Processing Record 37: illoqqortoormiut
# City not found. Skipping...
# Processing Record 38: bondo
# Processing Record 39: dingle
# Processing Record 40: new norfolk
# Processing Record 41: byumba
# Processing Record 42: albany
# Processing Record 43: vaitupu
# City not found. Skipping...
# Processing Record 44: caravelas
# Processing Record 45: castro
# Processing Record 46: guerrero negro
# Processing Record 47: ostrovnoy
# Processing Record 48: cherskiy
# Processing Record 49: camopi
# Processing Record 50: itoman
# Processing Record 51: barrow
# Processing Record 52: bengkulu
# City not found. Skipping...
# Processing Record 53: ribeira grande
# Processing Record 54: galiwinku
# City not found. Skipping...
# Processing Record 55: upernavik
# Processing Record 56: panama city
# Processing Record 57: taolanaro
# City not found. Skipping...
# Processing Record 58: butaritari
# Processing Record 59: sorong
# Processing Record 60: atar
# Processing Record 61: baoqing
# Processing Record 62: sonamura
# Processing Record 63: visby
# Processing Record 64: taoudenni
# Processing Record 65: vestmannaeyjar
# Processing Record 66: rocha
# Processing Record 67: port alfred
# Processing Record 68: codrington
# Processing Record 69: san carlos de bariloche
# Processing Record 70: kruisfontein
# Processing Record 71: kardla
# Processing Record 72: norway
# Processing Record 73: tidore
# City not found. Skipping...
# Processing Record 74: sentyabrskiy
# City not found. Skipping...
# Processing Record 75: richards bay
# Processing Record 76: pevek
# Processing Record 77: namatanai
# Processing Record 78: port hawkesbury
# Processing Record 79: saint george
# Processing Record 80: atuona
# Processing Record 81: yarim
# Processing Record 82: puerto ayora
# Processing Record 83: constitucion
# Processing Record 84: umm ruwabah
# City not found. Skipping...
# Processing Record 85: yulara
# Processing Record 86: mabaruma
# Processing Record 87: qaanaaq
# Processing Record 88: henties bay
# Processing Record 89: khargupur
# Processing Record 90: cockburn town
# Processing Record 91: atambua
# Processing Record 92: port augusta
# Processing Record 93: tiksi
# Processing Record 94: grindavik
# Processing Record 95: inhambane
# Processing Record 96: ancud
# Processing Record 97: beringovskiy
# Processing Record 98: esperance
# Processing Record 99: victoria
# Processing Record 100: cape town
# Processing Record 101: attawapiskat
# City not found. Skipping...
# Processing Record 102: nikolskoye
# Processing Record 103: chumikan
# Processing Record 104: bredasdorp
# Processing Record 105: chilakalurupet
# Processing Record 106: hermanus
# Processing Record 107: kulhudhuffushi
# Processing Record 108: roma
# Processing Record 109: lorengau
# Processing Record 110: tasiilaq
# Processing Record 111: sovetskaya gavan
# Processing Record 112: coos bay
# Processing Record 113: georgetown
# Processing Record 114: belushya guba
# City not found. Skipping...
# Processing Record 115: zhigansk
# Processing Record 116: bluff
# Processing Record 117: kodiak
# Processing Record 118: jalingo
# Processing Record 119: hasaki
# Processing Record 120: miles city
# Processing Record 121: lasa
# Processing Record 122: harper
# Processing Record 123: rafaela
# Processing Record 124: rungata
# City not found. Skipping...
# Processing Record 125: iqaluit
# Processing Record 126: ust-kalmanka
# Processing Record 127: tuktoyaktuk
# Processing Record 128: saleaula
# City not found. Skipping...
# Processing Record 129: sibolga
# Processing Record 130: lebu
# Processing Record 131: tautira
# Processing Record 132: hurghada
# City not found. Skipping...
# Processing Record 133: talnakh
# Processing Record 134: betafo
# Processing Record 135: baghdad
# Processing Record 136: east london
# Processing Record 137: pimenta bueno
# Processing Record 138: leningradskiy
# Processing Record 139: venado tuerto
# Processing Record 140: jamestown
# Processing Record 141: ballitoville
# Processing Record 142: mar del plata
# Processing Record 143: sola
# Processing Record 144: aktash
# City not found. Skipping...
# Processing Record 145: bubaque
# Processing Record 146: carnarvon
# Processing Record 147: dibulla
# Processing Record 148: lusambo
# Processing Record 149: robertsganj
# Processing Record 150: ostersund
# Processing Record 151: belmonte
# Processing Record 152: pacific grove
# Processing Record 153: carlsbad
# Processing Record 154: wewak
# Processing Record 155: yetholm
# City not found. Skipping...
# Processing Record 156: prince george
# Processing Record 157: kahului
# Processing Record 158: acapulco
# Processing Record 159: san policarpo
# Processing Record 160: puerto escondido
# Processing Record 161: arraial do cabo
# Processing Record 162: yingzhong
# City not found. Skipping...
# Processing Record 163: auki
# Processing Record 164: aykhal
# Processing Record 165: magan
# Processing Record 166: bud
# Processing Record 167: gunjur
# Processing Record 168: newcastle
# Processing Record 169: merrill
# Processing Record 170: shache
# Processing Record 171: pangody
# Processing Record 172: ariquemes
# Processing Record 173: cutro
# Processing Record 174: trenggalek
# Processing Record 175: natal
# Processing Record 176: suyan
# Processing Record 177: yasnyy
# Processing Record 178: fort saint john
# City not found. Skipping...
# Processing Record 179: coulihaut
# City not found. Skipping...
# Processing Record 180: lyngdal
# Processing Record 181: sorvag
# City not found. Skipping...
# Processing Record 182: te anau
# Processing Record 183: rubio
# Processing Record 184: adamovka
# Processing Record 185: ambulu
# Processing Record 186: klaksvik
# Processing Record 187: torbay
# Processing Record 188: adrar
# Processing Record 189: fuxin
# Processing Record 190: jega
# Processing Record 191: hobyo
# Processing Record 192: katsuura
# Processing Record 193: saldanha
# Processing Record 194: dikson
# Processing Record 195: uthal
# Processing Record 196: vuktyl
# Processing Record 197: hammerfest
# Processing Record 198: provideniya
# Processing Record 199: sangod
# Processing Record 200: whitehorse
# Processing Record 201: mago
# Processing Record 202: keti bandar
# Processing Record 203: bethel
# Processing Record 204: eureka
# Processing Record 205: kushmurun
# City not found. Skipping...
# Processing Record 206: nizhneyansk
# City not found. Skipping...
# Processing Record 207: nago
# Processing Record 208: san jose
# Processing Record 209: severo-kurilsk
# Processing Record 210: kiama
# Processing Record 211: sandwick
# Processing Record 212: moctezuma
# Processing Record 213: villa carlos paz
# Processing Record 214: hualmay
# Processing Record 215: chiredzi
# Processing Record 216: alice springs
# Processing Record 217: paita
# Processing Record 218: touros
# Processing Record 219: jiwani
# Processing Record 220: bambous virieux
# Processing Record 221: rawannawi
# City not found. Skipping...
# Processing Record 222: khasan
# Processing Record 223: airai
# Processing Record 224: sierra vista
# Processing Record 225: solano
# Processing Record 226: tomatlan
# Processing Record 227: palabuhanratu
# City not found. Skipping...
# Processing Record 228: ponta do sol
# Processing Record 229: matrei
# City not found. Skipping...
# Processing Record 230: viedma
# Processing Record 231: asilah
# City not found. Skipping...
# Processing Record 232: sobolevo
# Processing Record 233: grand river south east
# City not found. Skipping...
# Processing Record 234: panaba
# Processing Record 235: buraydah
# Processing Record 236: zaranj
# Processing Record 237: amderma
# City not found. Skipping...
# Processing Record 238: luena
# Processing Record 239: pisco
# Processing Record 240: haademeeste
# City not found. Skipping...
# Processing Record 241: mahebourg
# Processing Record 242: lewistown
# Processing Record 243: kalmunai
# Processing Record 244: batemans bay
# Processing Record 245: monrovia
# Processing Record 246: vangaindrano
# Processing Record 247: hedaru
# Processing Record 248: ilulissat
# Processing Record 249: dothan
# Processing Record 250: ginir
# Processing Record 251: itarema
# Processing Record 252: aklavik
# Processing Record 253: itamaraju
# Processing Record 254: cabo san lucas
# Processing Record 255: naze
# Processing Record 256: gurupi
# Processing Record 257: moron
# Processing Record 258: phan rang
# City not found. Skipping...
# Processing Record 259: nguiu
# City not found. Skipping...
# Processing Record 260: tabas
# Processing Record 261: manggar
# Processing Record 262: vila velha
# Processing Record 263: ternate
# Processing Record 264: comodoro rivadavia
# Processing Record 265: linkuva
# Processing Record 266: mergui
# City not found. Skipping...
# Processing Record 267: pedernales
# Processing Record 268: hambantota
# Processing Record 269: rincon
# Processing Record 270: shelburne
# Processing Record 271: solovetskiy
# City not found. Skipping...
# Processing Record 272: mys shmidta
# City not found. Skipping...
# Processing Record 273: wanlaweyn
# Processing Record 274: sharhorod
# Processing Record 275: vila do maio
# Processing Record 276: vardo
# Processing Record 277: guilin
# Processing Record 278: maldonado
# Processing Record 279: oppdal
# Processing Record 280: okha
# Processing Record 281: haibowan
# City not found. Skipping...
# Processing Record 282: tawau
# Processing Record 283: hurricane
# Processing Record 284: muli
# Processing Record 285: codajas
# Processing Record 286: moose factory
# Processing Record 287: saint-joseph
# Processing Record 288: champerico
# Processing Record 289: bargal
# City not found. Skipping...
# Processing Record 290: imuris
# Processing Record 291: vila franca do campo
# Processing Record 292: sakaiminato
# Processing Record 293: gari
# Processing Record 294: kolvereid
# Processing Record 295: mporokoso
# Processing Record 296: vilyuysk
# Processing Record 297: eirunepe
# Processing Record 298: skibbereen
# Processing Record 299: xai-xai
# Processing Record 300: menongue
# Processing Record 301: sorland
# Processing Record 302: aksha
# Processing Record 303: west odessa
# Processing Record 304: qaqortoq
# Processing Record 305: san jeronimo
# Processing Record 306: kankavli
# City not found. Skipping...
# Processing Record 307: tete
# Processing Record 308: christchurch
# Processing Record 309: fez
# Processing Record 310: bonthe
# Processing Record 311: killybegs
# Processing Record 312: brae
# Processing Record 313: kincardine
# Processing Record 314: byron bay
# Processing Record 315: los llanos de aridane
# Processing Record 316: san andres
# Processing Record 317: puquio
# Processing Record 318: cidreira
# Processing Record 319: akureyri
# Processing Record 320: paka
# Processing Record 321: lodwar
# Processing Record 322: nabire
# Processing Record 323: tukrah
# City not found. Skipping...
# Processing Record 324: quatre cocos
# Processing Record 325: baykit
# Processing Record 326: ico
# Processing Record 327: sangar
# Processing Record 328: san vicente
# Processing Record 329: sampit
# Processing Record 330: rajapur
# Processing Record 331: college
# Processing Record 332: edson
# Processing Record 333: gat
# Processing Record 334: wanderlandia
# City not found. Skipping...
# Processing Record 335: grunstadt
# Processing Record 336: oskaloosa
# Processing Record 337: nemuro
# Processing Record 338: yverdon
# City not found. Skipping...
# Processing Record 339: mackay
# Processing Record 340: basco
# Processing Record 341: faya
# Processing Record 342: morondava
# Processing Record 343: half moon bay
# Processing Record 344: rancho palos verdes
# Processing Record 345: damara
# Processing Record 346: saskylakh
# Processing Record 347: tazovskiy
# Processing Record 348: yar-sale
# Processing Record 349: kawalu
# Processing Record 350: namibe
# Processing Record 351: manoharpur
# Processing Record 352: muros
# Processing Record 353: hithadhoo
# Processing Record 354: stoyba
# City not found. Skipping...
# Processing Record 355: nanortalik
# Processing Record 356: san patricio
# Processing Record 357: chadiza
# Processing Record 358: marsa matruh
# Processing Record 359: uberaba
# Processing Record 360: port lincoln
# Processing Record 361: agra
# Processing Record 362: tonkino
# Processing Record 363: ambunti
# Processing Record 364: leh
# Processing Record 365: agadez
# Processing Record 366: cozumel
# City not found. Skipping...
# Processing Record 367: marseille
# Processing Record 368: rawson
# Processing Record 369: arlit
# Processing Record 370: hofn
# Processing Record 371: klamath falls
# Processing Record 372: osorno
# Processing Record 373: sahrak
# City not found. Skipping...
# Processing Record 374: shamkhal
# Processing Record 375: buala
# Processing Record 376: kuche
# City not found. Skipping...
# Processing Record 377: villeneuve-sur-lot
# Processing Record 378: bah
# Processing Record 379: ambilobe
# Processing Record 380: gloversville
# Processing Record 381: abha
# Processing Record 382: fortuna
# Processing Record 383: axim
# Processing Record 384: broome
# Processing Record 385: mount gambier
# Processing Record 386: palmer
# Processing Record 387: valparai
# Processing Record 388: port hardy
# Processing Record 389: gurskoye
# City not found. Skipping...
# Processing Record 390: abu samrah
# Processing Record 391: bardiyah
# City not found. Skipping...
# Processing Record 392: urumqi
# City not found. Skipping...
# Processing Record 393: kathu
# Processing Record 394: cambyreta
# City not found. Skipping...
# Processing Record 395: cabedelo
# Processing Record 396: hecun
# Processing Record 397: kozhva
# Processing Record 398: poum
# Processing Record 399: ati
# Processing Record 400: ahar
# Processing Record 401: havre-saint-pierre
# Processing Record 402: walvis bay
# Processing Record 403: mayo
# Processing Record 404: matagami
# Processing Record 405: temba
# Processing Record 406: khovu-aksy
# Processing Record 407: phalaborwa
# Processing Record 408: hami
# Processing Record 409: nome
# Processing Record 410: oriximina
# Processing Record 411: pegnitz
# Processing Record 412: muisne
# Processing Record 413: anchorage
# Processing Record 414: hovd
# Processing Record 415: kenai
# Processing Record 416: taraza
# City not found. Skipping...
# Processing Record 417: tasbuget
# City not found. Skipping...
# Processing Record 418: alekseyevka
# Processing Record 419: tambul
# City not found. Skipping...
# Processing Record 420: terra santa
# Processing Record 421: samarai
# Processing Record 422: kristiansund
# Processing Record 423: cooma
# Processing Record 424: san juan
# Processing Record 425: lagoa
# Processing Record 426: watsa
# Processing Record 427: mbarara
# Processing Record 428: shizunai
# Processing Record 429: villazon
# City not found. Skipping...
# Processing Record 430: lima
# Processing Record 431: nakamura
# Processing Record 432: pudozh
# Processing Record 433: barbar
# City not found. Skipping...
# Processing Record 434: mehamn
# Processing Record 435: lufilufi
# Processing Record 436: mazyr
# Processing Record 437: nam tha
# City not found. Skipping...
# Processing Record 438: haines junction
# Processing Record 439: witney
# Processing Record 440: khed brahma
# Processing Record 441: carroll
# Processing Record 442: esna
# Processing Record 443: zimmi
# Processing Record 444: fukue
# Processing Record 445: shemonaikha
# Processing Record 446: omsukchan
# Processing Record 447: urdzhar
# City not found. Skipping...
# Processing Record 448: bakal
# Processing Record 449: zima
# Processing Record 450: petropavlovsk-kamchatskiy
# Processing Record 451: santa cruz
# Processing Record 452: najran
# Processing Record 453: praia da vitoria
# Processing Record 454: mahajanga
# Processing Record 455: cheney
# Processing Record 456: lodja
# Processing Record 457: benghazi
# Processing Record 458: newport
# Processing Record 459: luderitz
# Processing Record 460: godda
# Processing Record 461: batagay
# Processing Record 462: paluan
# Processing Record 463: goderich
# Processing Record 464: thinadhoo
# Processing Record 465: jumla
# Processing Record 466: kijang
# Processing Record 467: halifax
# Processing Record 468: teluknaga
# Processing Record 469: palanga
# Processing Record 470: razdolinsk
# Processing Record 471: ciudad guayana
# Processing Record 472: tamiahua
# Processing Record 473: kalomo
# City not found. Skipping...
# Processing Record 474: beyla
# Processing Record 475: sesheke
# Processing Record 476: benguela
# Processing Record 477: teguldet
# Processing Record 478: auburn
# Processing Record 479: barawe
# City not found. Skipping...
# Processing Record 480: virginia beach
# Processing Record 481: portland
# Processing Record 482: fonte boa
# Processing Record 483: hirara
# Processing Record 484: buchanan
# Processing Record 485: igarka
# Processing Record 486: zhanaozen
# Processing Record 487: worland
# Processing Record 488: groningen
# Processing Record 489: ksenyevka
# City not found. Skipping...
# Processing Record 490: kudahuvadhoo
# Processing Record 491: sumbawa
# City not found. Skipping...
# Processing Record 492: moa
# Processing Record 493: novoagansk
# Processing Record 494: srednekolymsk
# Processing Record 495: semey
# Processing Record 496: yatou
# Processing Record 497: burica
# City not found. Skipping...
# Processing Record 498: aden
# Processing Record 499: cayenne
# Processing Record 500: slave lake
# Processing Record 501: moranbah
# Processing Record 502: cap-aux-meules
# Processing Record 503: azuaga
# Processing Record 504: norman wells
# Processing Record 505: port-gentil
# Processing Record 506: olafsvik
# City not found. Skipping...
# Processing Record 507: tura
# Processing Record 508: rokupr
# Processing Record 509: salalah
# Processing Record 510: waipawa
# Processing Record 511: coahuayana
# Processing Record 512: cotonou
# Processing Record 513: mumford
# Processing Record 514: saint andrews
# Processing Record 515: mandsaur
# Processing Record 516: ponta delgada
# Processing Record 517: saint-paul
# Processing Record 518: kryvyy rih
# Processing Record 519: urucara
# Processing Record 520: poquoson
# Processing Record 521: zhangjiakou
# Processing Record 522: seymchan
# Processing Record 523: jiayuguan
# Processing Record 524: sabang
# Processing Record 525: hay river
# Processing Record 526: bolshaya sosnova
# Processing Record 527: fort nelson
# Processing Record 528: moindou
# Processing Record 529: punta de bombon
# Processing Record 530: paraiso
# Processing Record 531: vung tau
# Processing Record 532: concordia
# Processing Record 533: gigmoto
# Processing Record 534: ahipara
# Processing Record 535: morehead
# Processing Record 536: joshimath
# Processing Record 537: korla
# City not found. Skipping...
# Processing Record 538: pangnirtung
# Processing Record 539: lavrentiya
# Processing Record 540: guatire
# Processing Record 541: la ronge
# Processing Record 542: umaria
# Processing Record 543: necochea
# Processing Record 544: redcar
# Processing Record 545: cururupu
# Processing Record 546: tabuk
# Processing Record 547: serbanesti

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {
    "City": good_cities,
    "Latitude": lats,
    "Longitude": longs,
    "Temperature": temp,
    "Humidity":hums,
    "Cloudiness":cloud,
    "Wind Speed":wndspd,
    "Country":country,
    "Date":date
}

weather_data = pd.DataFrame(weather_dict)
weather_data.to_csv(r'..\weather_data.csv')
weather_data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-1fa2f8781242> in <module>
#       1 weather_dict = {
# ----> 2     "City": good_cities,
#       3     "Latitude": lats,
#       4     "Longitude": longs,
#       5     "Temperature": temp,
#
# NameError: name 'good_cities' is not defined

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
weatherdf = pd.read_csv("../weather_data.csv")

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.rc('figure', figsize=(13,6))
plt.rcParams.update({'font.size':19})

fig, ax = plt.subplots()
ax.set_title(f'Latitutde vs Temperature (4/20/19)')
weatherdf.plot(kind='scatter', 
               x='Latitude', 
               y='Temperature', 
               c='Longitude', 
               cmap='Reds', 
               grid=True, 
               ax=ax)
ax.set_axisbelow(True)
plt.savefig('Latitutde vs Temperature2.png')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
fig, ax = plt.subplots()
ax.set_title(f'Latitutde vs Humidity (4/20/19)')
weatherdf.plot(kind='scatter', 
               x='Latitude', 
               y='Humidity', 
               c='Longitude', 
               cmap='Reds', 
               ax=ax,
               grid=True) 
ax.set_axisbelow(True)

plt.savefig('Latitutde vs Humidity.png')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
fig, ax = plt.subplots()
ax.set_title(f'Latitutde vs Cloudiness (4/20/19)')
weatherdf.plot(kind='scatter', 
               x='Latitude', 
               y='Cloudiness', 
               c='Longitude', 
               cmap='Reds', 
               ax=ax,
               grid=True) 
ax.set_axisbelow(True) 

plt.savefig('Latitutde vs Cloudiness.png')

# %%
fig, ax = plt.subplots()
ax.set_title(f'Latitutde vs Wind Speed (4/20/19)')
weatherdf.plot(kind='scatter', 
               x='Latitude', 
               y='Wind Speed', 
               c='Longitude', 
               cmap='Reds', 
               ax=ax,
               grid=True) 
ax.set_axisbelow(True) 

plt.savefig('Latitutde vs Wind Speed.png')
